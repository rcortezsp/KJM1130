# %% [markdown]
# <div style="background-image: url('bg29.png');width:990;height:145px;display:table;">
#     <table style="margin:0px;width:100%;height:100%">
#         <tr style="background-color:rgba(0, 0, 0, 0);"><td>
#                  <img src="bubblebox_logo4.png" alt="Forest" style="width:90%;" align="right">
#             </td>
#             <td></td>
#             <td>
#             <td></td>
#             <td>
#                 <img src="https://www.mn.uio.no/hylleraas/english/about/internal/graphical-profile/visual-profile/hylleraas-%E2%80%93-logo-%E2%80%93-screen-%E2%80%93-rgb.png" alt="Forest" style="width:80%;" align="right">
#                 </td>
#                 <td>
#                 <img src="https://upload.wikimedia.org/wikipedia/commons/f/f4/UiO_logo.png" style="width:30%">
#             </td>
#         </tr>
#     </table>
# </div>

# %% [markdown]
# ### KJM1130 - Fysikalsk Kjemi I
# # Beregningslab 1 : Tilstand, endring og likevekt
#
# ---
#
# #### Utviklet av Audun Skau Hansen ( a.s.hansen@kjemi.uio.no ) ved Kjemisk institutt, Hylleraas Senteret, Universitetet i Oslo (2021)

# %% [markdown]
# <div class="list-group" id="list-tab" role="tablist">
#   <h3 class="list-group-item list-group-item-action active" data-toggle="list"  role="tab" aria-controls="home" style = "background-color:rgba(30, 00, 10, .7);border-color:rgba(0, 0, 0, 1)">Innhold</h3>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#Innledning" role="tab" aria-controls="profile">Innledning<span class="badge badge-primary badge-pill">1</span></a>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#Tilstander" role="tab" aria-controls="messages">Tilstander<span class="badge badge-primary badge-pill">2</span></a>
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#Endring" role="tab" aria-controls="settings">Endring<span class="badge badge-primary badge-pill">3</span></a>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#Systemet" role="tab" aria-controls="settings">Systemet<span class="badge badge-primary badge-pill">4</span></a>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#Likevekt" role="tab" aria-controls="settings">Likevekt<span class="badge badge-primary badge-pill">5</span></a>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#Lesestoff" role="tab" aria-controls="settings">Les mer om molekylsimuleringer<span class="badge badge-primary badge-pill">5</span></a>
#     <a class="list-group-item list-group-item-action" data-toggle="list" href="#Innleveringsoppgaver" role="tab" aria-controls="settings">Oppgaver<span class="badge badge-primary badge-pill">6</span></a>
# </div>

# %% [markdown]
# # Innledning
# <div style="margin:0px">
# <table style="margin:0px;width:100%;height:100%;">
# <tr style="background-color:rgba(0, 0, 0, 0);width:100%">
#     <td>
# <font size="3" face="Courier New" >
#     <p></p>
# <p>En utfordring vi møter i fysikalsk kjemi er å forstå koblingene mellom det som foregår på molekylært nivå og det vi observerer makroskopisk. Størrelser som trykk, temperatur og reaksjonsrate gir intuitivt mening på laboratoriet, men blir langt mer abstrakte når vi ser på små samlinger av enkeltmolekyler. På samme måte vil du ofte finne at det ikke er egenskapene til det enkelte molekyl som alene bestemmer hvordan systemet oppfører seg som helhet, det som foregår i relasjonene mellom molekylene kan være vel så avgjørende.</p>
#     </td>
# </tr>
# </table>
# <table style="margin:0px;width:100%;height:100%;">
#         <tr style="background-color:rgba(0, 0, 0, 0);width:50%;">
#             <td style="text-align: left; vertical-align: upper;"><font size="3" face="Courier New" align = "center" >
#                 <p>Samtidig beskriver både den mikroskopiske og makroskopiske tilnærmingen akkurat den samme virkeligheten, og det å forstå hvordan disse rammeverkene henger sammen vil gi deg en dypere og mer helhetlig forståelse av kjemi.</p>
# <p>Tradisjonelt går veien mellom disse ytterpunktene gjennom et utpreget matematisk landskap - det er tross alt slik vi har formulert termodynamikken. Med lett tilgjengelige modelleringsverktøy kan vi imidlertid tilby en ny, og muligens litt mer intuitiv vei, som kan knytte en nære forbindelser mellom eksperiment og teori.</p>
#                 <p><b>BubbleBox</b> er et regneverktøy som har til hensikt å gi deg kjemisk forståelse gjennom modellering. Ved å fokusere på enkle, numeriske modeller, hvor vi setter søkelyset på de mest sentrale aspektene i de relevante temaene, håper vi å kunne hjelpe deg til å oppnå bedre forståelse for konsepter i fysikalsk kjemi. Samtidig bør du merke deg at BubbleBox ikke er utformet for å gjøre vitenskapelig forskning - til det finnes det <a href="https://en.wikipedia.org/wiki/Category:Molecular_modelling_software">mange</a> langt mer egnede verktøy. Modellene vi skal se på vil inneholde akkurat de samme fenomenene som omtales i pensum, men i en langt mer rendyrket og enkel form. Idealiserte modeller er ofte akkurat slik; de inneholder nok kompleksitet til å representere det vi ønsker å undersøke, og lar oss se bort fra virkelighetens kompliserende sammensurium.</p>
# <p>
#             </td>
#             <td>
#                 <img src="macro.png" style="width:80%; align: center">
#             </td>
#         </tr>
# </table>
# <table style="margin:0px;width:100%;height:100%;">
# <tr style="background-color:rgba(0, 0, 0, 0);width:100%">
#     <td>
# <font size="3" face="Courier New" align = "center" >
# <p>Vi har utformet fire Jupyter Notebooks for å hjelpe deg i KJM1130 dette semesteret. I denne første, som vi har kalt <i>"Tilstand, endring og likevekt"</i>, skal du lære deg noen grunnleggende fremgangsmåter for å gjennomføre et numerisk eksperiment med <b>BubbleBox</b>. Du vil bli kjent med et system som kalles for en <i>todimensjonal Lennard-Jones væske</i>, som kjennetegnes ved måten molekylene dytter og drar i hverandre på. Til sist skal vi se på noen enkle måter å analysere resultatene av eksperimentet. I tre trinn skal du gjennomføre et eksperiment omtrent på samme måte som du gjør på laben:</p>
# <img src="123.png" style="width:60%">
# <p>Du vil først klargjøre en prøve, deretter la en reaksjon utfolde seg, før du avslutningsvis analyserer resultatene dine. Disse tre trinnene vil gå igjen i alle eksperimentene du utfører i BubbleBox dette semesteret, og Python-skriptene du skriver vil i grove trekk se ut som følger:</p>
# </td>
# </tr>
# </table>
#
# ```python3
# s = bb.box( ... )       # 1. Klargjør en prøve
#
# s.evolve( ... )            # 2. La tiden gå noen sekunder
#
# E_k =  s.mass*s.vel**2 / 2 # 3. Analyser resultatene (i dette tilfellet regnes kinetisk energi)
# ```
#
# <table style="margin:0px;width:100%;height:100%;">
# <tr style="background-color:rgba(0, 0, 0, 0);width:100%">
#     <td>
# <font size="3" face="Courier New" align = "center" >
# <p>Du vil kunne kjøre kode-eksemplene interaktivt underveis, og vi oppfordrer deg å forandre på kodeblokkene for å se hva som skjer når du endrer parametrene.</p>
# </td>
# </tr>
# </table>

# %% [markdown]
# ---

# %% [markdown]
# # Tilstander

# %% [markdown]
# <table style="margin:0px;width:100%;height:100%;">
# <tr style="background-color:rgba(0, 0, 0, 0);width:100%">
#     <td>
# <font size="3" face="Courier New" align = "center" >
#     <p>Et <i>system</i> er en samling molekyler som kan vekselvirke (dytte og trekke på hverandre) under visse betingelser. Disse betingelsene kan være gitt ved <i>randbetingelser</i> altså hvilke regler som gjelder når molekylene når randen av systemet, og det kan være <i>initialbetingelser</i>, altså hvordan molekylene er definert ved tiden 0.</p>
#     <p>Et system har - i likhet med et enkeltmolekyl - et sett <i>koordinater</i> som definerer systemets tilstand. Der hvor et monatomisk molekyl i tre dimensjoner som regel kan defineres ved 6 koordinater; 3 for posisjon og 3 for hastighet, kan systemet som helhet defineres ved $6N$ koordinater, hvor $N$ er antall molekyler i systemet. (Vi ser her bort fra elektronenes frihetsgrader).</p>
#     <p>Et gitt sett med koordinater svarer til en såkalt <i>mikrotilstand</i>, hvor vi kjenner alt som er å vite om systemet. Generelt finner vi at mange ulike mikrotilstander kan resultere i de samme målingene på makroskopisk nivå, slik som for eksempel temperatur, og vi sier derfor at alle slike like mikrotilstander svarer til den samme <i>makrotilstanden</i>. En makrotilstand er bestemt for et isolert system ved energi, volum og antall partikler. </p>
# <p>I et realistisk laboratorieforsøk er antallet mikrotilstander som regel for stort til å kunne bestemmes, og det viser seg dessuten at vi ikke behøver å vite eksakt hvilken mikrotilstand systemet befinner seg i for å forutsi hvordan systemet utvikler seg. Det er derfor de fleste ligningene du benytter i KJM1130 ikke inneholder et utall partikkelposisjoner, men snarere makroskopiske variable som trykk og temperatur. I et numerisk forsøk, slik vi nå skal sette opp, vil vi derimot kjenne alle detaljer om systemet vi modellerer, hvilket gir oss en unik mulighet til å forstå sammenhengen mellom mikro- og makrotilstander. </p>
#     <p>
#     La oss til å begynne med sette opp et system med BubbleBox og visualisere mikrotilstanden det befinner seg i:
#     </p>
# </td>
# </tr>
# </table>
# <p></p>

# %%
## INSTRUKSJONER: Klikk på denne kodeblokken og trykk CTRL+ENTER for å kjøre den

# %matplotlib notebook  

import hylleraas.bubblebox as bb  # importer modulen bubblebox som "bb"

s = bb.box(n_bubbles = 36, vel = 1, box = (10,10))  # 1. Klargjør et system med 30 identiske molekyler

s.visualize_state()  # Vis en figur av tilstanden
# Out:
# <img src="data:image/png;base64,..." width="400">

# %% [markdown]
# <table style="margin:0px;width:100%;height:100%;">
# <tr style="background-color:rgba(0, 0, 0, 0);width:100%">
#     <td>
# <font size="3" face="Courier New" align = "left" >
#     <p>
#         Om du har kjørt cellen over korrekt vil du se 30 bobler som representerer molekylene i systemet. Hvert av molekylene har en posisjon i det kartesiske X-Y koordinatsystemet, markert med en sort "•", i tillegg til en hastighet, visualisert med en vektor pekenede ut fra molekylets posisjon. Hastigheten har dermed både en retning, vist med pilens retning, og en magnitude, indikert med pilens lengde.
#     </p>
#     <p>
#         Boblene er omsluttet av en sort boks som markerer randen på systemet. Randbetingelsene er reglene for hva som skjer om molekylene treffer randen; vil de passere upåvirket eller kollidere med en vegg? Dette, sammen med måten molekylene vekselvirker, er noe vi må definere i tillegg til posisjonene.
#     </p>
#     <div class="alert alert-info" role="alert" align="left">
#         <h3>DISKUSJON</h3>
# Inneholder randbetingelsene og alle molekylenes posisjon og hastighet nok informasjon til å forutsi alt som er å vite om dette systemet for all fremtid, eller trenger vi noe mer? Tenk gjennom eller diskuter gruppevis.
# </div>
# </td>
# </tr>
# </table>

# %% [markdown]
# ---

# %% [markdown]
# # Endring

# %% [markdown]
# <div style="margin:0px">
# <table style="margin:0px;width:100%;height:100%;">
# <tr style="background-color:rgba(0, 0, 0, 0);width:100%">
#     <td>
# <font size="3" face="Courier New" >
#     <p></p>
# <p><font size="3" face="Courier New" align = "center" >Når vi lar tiden begynne å gå vil kreftene virke mellom molekylene. De vil trekke og dytte på hverandre slik at systemets koordinater endrer seg. Samtidig som enkeltmolekylene endrer posisjon og hastighet, forflyttes systemet som helhet mellom ulike mikrotilstander. Dette litt mer abstrakte bildet på bevegelse gjennom rommet av tilstander omtales ofte som <i>tidens pil</i>, og kan hjelpe deg til å oppnå en dypere forståelse av termodynamikkens annen lov.</p>
#         <p>Hver inkrementelle endring av tiden medfører altså som regel en endring av systemets mikrotilstand, men du vil samtidig oppleve at noe endrer seg mindre og mindre ettersom tiden går, nemlig størrelser som temperatur og trykk. Etter en stund vil du finne at det disse størrelsene fluktuerer omkring gjennomsnittsverdier, noe som kan tolkes som at systemet er i <i>likevekt</i>. </p>
#         <p>Det finnes flere måter å la tiden gå på i BubbleBox. Alle de følgende metodene avanserer systemet med ett eller flere tidssteg: </p>
#     </td>
# </tr>
# </table>
#
# ```python3
# s.advance(dt = 0.001)           # Ett enkelt tidssteg
#
# s.run(dt = 0.001)               # Kjøring med animert visualisering
#
# s.evolve(t = 1.0, dt = 0.001)   # La systemet utvikle seg i 1 sekund
# ```
#
# <table style="margin:0px;width:100%;height:100%;">
# <tr style="background-color:rgba(0, 0, 0, 0);width:100%">
#     <td>
# <font size="3" face="Courier New" align = "center" >
# <p>For hvert tidsinkrement beregnes kreftene i systemet og følgelig molekylenes akselerasjon, hvorpå det tas et lite tidssteg på $dt$ sekunder. Du kan åpne modulen <a href="bubblebox.py">BubbleBox.py</a> for å se nærmere på hvordan vi løser bevegelsesligningene i tid, det baserer seg på metodikk du har møtt før i forbindelse med <i>Eulers Metode</i>. For å gi deg en intuitiv forståelse av hva som skjer når tiden går i systemet kan du kjøre kodecellen under:</p>
# </td>
# </tr>
# </table>

# %%
## INSTRUKSJONER: Klikk på denne kodeblokken og trykk CTRL+ENTER for å kjøre den
##                Avslutt simuleringen ved å trykke på den blå knappen når du har sett nok.

s = bb.box(n_bubbles = 30, vel = 4, box = (10,10), relax = False)  # 1. Klargjør et system med 30 identiske molekyler

s.dt = 0.001

s.run() #la tiden gå
# Out:
# <img src="data:image/png;base64,..." width="400">

# %% [markdown]
# <table style="margin:0px;width:100%;height:100%;">
# <tr style="background-color:rgba(0, 0, 0, 0);width:100%">
#     <td>
# <font size="3" face="Courier New" align = "center" >
# <p>Om du har gjort alt riktig vil du se 30 små molekyler forflytte seg rundt i boksen og vekselvirke med hverandre. Det kan være nyttig med slik "sanntidsvisualisering" av simuleringen for å forstå hva som foregår i systemet. På sikt vil du sannsynligvis ønske å kjøre det i bakgrunnen og heller kun analysere slutt-tilstandene, ettersom det som regel er her den interessante informasjonen ligger.</p>
# </td>
# </tr>
# </table>

# %% [markdown]
# <div class="alert alert-info" role="alert" align="left">
#     <font size="3" face="Courier New" align = "center" >
# <h3>DISKUSJON</h3>
# <p>Kjør simuleringen en gang til og diskuter eller tenk gjennom følgende:</p>
# <p>1. Hva skjer når molekylene kolliderer?</p>
# <p>2. Hvordan forholder molekylene seg til veggene?</p>
# <p>3. Beveger molekylene seg i rette eller krumme linjer?</p>
# <p>4. Kan du finne noen par eller grupper av molekyler som holder sammen?</p>
# <p>5. I hvilken retning peker <i>tidens pil</i>? Hvor starter den? Diskuter med utgangspunkt i systemet vi presenterer over.</p>
# </div>

# %% [markdown]
# ---

# %% [markdown]
# # Systemet
# ### En todimensjonal Lennard-Jones væske

# %% [markdown]
# <div style="margin:0px">
# <table style="margin:0px;width:100%;height:100%;">
# <tr style="background-color:rgba(0, 0, 0, 0);width:100%">
#     <td>
# <font size="3" face="Courier New" >
#     <p></p>
# <p>Kreftene som virker mellom molekyler i reelle kjemiske systemer skyldes elektrostatiske og kvantemekaniske interaksjoner mellom elektroner og protoner. I vårt tilfelle vil vi basere oss på den generelle observasjonen at mange molekyler trekkes mot hverandre på lange avstander, men støtes vekk fra hverandre på korte avstander. I akkurat passe avstand kan de derfor i blant inngå bindinger og holde sammen i par eller små grupper, og det er også mulig for molekyler å inngå i større gitterstrukturer slik som i en krystall.</p
#     </td>
# </tr>
# </table>
# <table style="margin:0px;width:100%;height:100%;">
#         <tr style="background-color:rgba(0, 0, 0, 0);width:50%;">
#             <td style="text-align: left; vertical-align: upper;"><font size="3" face="Courier New" align = "center" >
# <p>Vi kan modellere all denne oppførselen med en enkel modell hvor interaksjonen mellom molekylene er beskrevet med <i>Lennard-Jones krefter</i>, gitt ved uttrykket</p>
# <p></p>
# \begin{equation}
# \mathbf{F}_{ij} = \epsilon \Big{(} \big{(}\frac{\sigma}{r_{ij}} \big{)}^6 - \big{(}\frac{\sigma}{r_{ij}} \big{)}^{12} \Big{)} \frac{\mathbf{r_{ij}}}{ r_{ij}^2 }. \quad \quad (1)
# \end{equation}
#                 <p></p>
#                 <p>Her er $\mathbf{r}_{ij} = \mathbf{r}_j - \mathbf{r}_i$ vektoren mellom molekylene $i$ og $j$, med avstanden $r_{ij}$, og parameterne $\sigma$ og $\epsilon$ gis passende tallverdier. Inntil videre kan du anta at $\sigma = \epsilon = 1$, noe som forenkler uttrykket betydelig. </p>
#                 <p>I figuren til høyre kan du se hvordan kraften mellom to molekyler virker frastøtende for små verdier av $r_{ij}$, og tiltrekkende for større avstander. </p>
#             </td>
#             <td>
#                 <img src="test2.gif" style="width:50%; align: center">
#             </td>
#         </tr>
# </table>
# <table style="margin:0px;width:100%;height:100%;">
# <tr style="background-color:rgba(0, 0, 0, 0);width:100%">
#     <td>
# <font size="3" face="Courier New" align = "center" >
# <p></p>
# </td>
# </tr>
# </table>
#
# <table style="margin:0px;width:100%;height:100%;">
# <tr style="background-color:rgba(0, 0, 0, 0);width:100%">
#     <td>
# <font size="3" face="Courier New" align = "center" >
#     <p>
# Kraften som virker på et enkelt molekyl i systemet vil være summen av alle kreftene fra de andre molekylene. Matematisk kan vi uttrykke dette som
#     <p></p>
#         \begin{equation}
# \mathbf{F}_{i} = \sum_{j \neq i} \mathbf{F}_{ij}. \quad \quad (2)
# \end{equation}
#     </p>
#     <p>
#     Det er nyttig for deg å vite dette, for det forklarer også hvorfor slike modeller kan være kostbare å regne på; for hver inkrementell endring av tid i simuleringen må vi regne kreftene for hvert par av molekyler, summere dem sammen og fra dette bestemme akselerasjonen til det enkelte molekyl.
#     </p>
#         <p>Når vi velger at molekylene skal vekselvirke på denne måten, og vi i tillegg begrenser molekylenes bevegelse til 2 dimensjoner ved å la posisjoner, hastighet og krefter beskrives av todimensjonale vektorer, vil systemet vi modellerer konvensjonelt kalles en <i> todimensjonal Lennard-Jones væske</i>. Du kan lese mer om slike modeller <a href="her">her</a>.</p>
#     <div class="alert alert-info" role="alert" align="left">
#         <h3>DISKUSJON</h3>
#         <p>Uttrykket for Lennard-Jones kraften i likning (1) inneholder to ledd. </p>
#         <p>(a) Skriv ned uttrykket på en tavle og identifiser hvilken funksjon de enkelte leddene har med hensyn på fortegn og potenser. </p>
#         <p>(b) Hvilken konsekvens ville det hatt om du reverserte fortegnet på denne kraften? </p>
#         <p>(c) Hvor er kraften lik null? (Det kan forekomme flere steder.)</p>
#         <p>(d) Vis at $\mathbf{F}_{ij} = -\mathbf{F}_{ji}$.</p>
# </div>
# </td>
# </tr>
# </table>

# %% [markdown]
# # Likevekt
# <table style="margin:0px;width:100%;height:100%;">
# <tr style="background-color:rgba(0, 0, 0, 0);width:100%">
#     <td>
# <font size="3" face="Courier New" align = "center" >
# <p>Du har nå sett hvordan du lager en todimensjonal Lennard-Jones væske med BubbleBox og hvordan du lar den uvikle seg i tid. Du spør deg kanskje; <i>hva ønsker vi å oppnå med å la dette systemet utvikle seg</i>? <i>Når er det i mål</i>? </p>
#     <p>Det korte svaret er at vi er i mål når det <i>ikke lenger skjer noe interessant</i> i systemet. På samme måte som i et laboratorieforsøk må vi definere et kriterium for når reaksjonen er over, og når det er tid for å analysere resultatene.
#     </p>
# <p>På laboraoriumet vil du muligens gjøre observasjoner av opphør i tempereratur- eller faseendringer, og bruke disse som indikasjon på at reaksjonen er over. I numeriske forsøk, slik du skal utføre i BubbleBox, kan du benytte tilsvarende observasjoner, for eksempel opphør av endring i kinetisk energi. Disse observasjonene forteller deg at systemet har oppnådd <i>likevekt</i>, altså at det befinner seg i den mest sannsynlige makrotilstanden. </p>
#     <p>La oss derfor se nærmere på hvordan den kinetiske energien i systemet varierer over tid. Vi trenger først å kunne regne denne energien, som for et molekyl $i$ er uttrykt ved:</p>
#     <p></p>
#     \begin{equation}
#     E_{K,i} = \frac{1}{2} m_i v_i^2. \quad \quad (3)
#     \end{equation}
#     <p></p>
#     <p>Her er $m_i$ massen til molekyl $i$ og $v_i^2 = v_{x,i}^2 +   v_{y,i}^2$ (i to dimensjoner). For systemet som helhet er den kinetiske energien derfor</p>
#     <p></p>
#     \begin{equation}
#     E_{K} = \sum_i^{N} E_{K,i}, \quad \quad (4)
#     \end{equation}
#     <p></p>
#     <p>hvor N er antall molekyler. For å regne denne trenger vi altså å vite massen og hastigheten til molekylene, og i BubbleBox er disse til enhver tid tilgjengelig i numpy-arrays som:</p>
#     <p></p>
# </td>
# </tr>
# </table>

# %%
print("Alle hastigheter           :")
print(s.vel)    
print(" ") #mellomrom
print("Hastigheten til partikkel 0:", s.vel[:,0]) 
print(" ") #mellomrom
print("Alle massene               :")
print(s.masses) 
print(" ") #mellomrom
print("Massen til molekyl 0:", s.masses[0])

# %% [markdown]
# <table style="margin:0px;width:100%;height:100%;">
# <tr style="background-color:rgba(0, 0, 0, 0);width:100%">
#     <td>
# <font size="3" face="Courier New" align = "center" >
# <p>Det er derfor mulig å beregne systemets kinetiske energi med funksjonene (vi ser for øyeblikket bort fra enheter):</p>
# </td>
# </tr>
# </table>

# %%
def kinetic_energy_readable(system):
    # Funksjon med hensyn på leselighet
    
    n_molecules = system.vel.shape[1] #antall molekyler
    
    E_k = 0 # kinetisk energi
    
    for i in range(n_molecules): #summer sammen enkeltenergier
        m_i = system.masses[i] # massen til molekyl i
        v_ix = system.vel[0,i] # x-komponenten til hastigheten til molekyl i
        v_iy = system.vel[1,i] # y-komponenten til hastigheten til molekyl i
    
        E_k = E_k + 0.5 * m_i *(v_ix**2 + v_iy**2) 
    
    return E_k


def kinetic_energy_fast(system):
    # Vektorisert funksjon med hensyn på ytelse
    return .5*bb.np.sum(system.masses*bb.np.sum(system.vel**2, axis = 0))


print("Total kinetisk energi (leselig): %.2f" % kinetic_energy_readable(s))
print("Total kinetisk energi ( kjapp ): %.2f" % kinetic_energy_fast(s))

# %% [markdown]
# <table style="margin:0px;width:100%;height:100%;">
# <tr style="background-color:rgba(0, 0, 0, 0);width:100%">
#     <td>
# <font size="3" face="Courier New" align = "center" >
# <p>Med disse funksjonene kan vi nå til slutt kjøre en simulering hvor vi ser hvordan den kinetiske energien utvikler seg over tid. Forsikre deg om at du i grove trekk forstår de enkelte trinnene som utføres under:</p>
# </td>
# </tr>
# </table>

# %%
#s = bb.sample(N_bubbles = 100, v0 = .25, L =25) # 50 molekyler 
                                                 # med maksimal starthastighet .25
                                                 # i en lukket boks i intervallet (-L, L)

s = bb.box(n_bubbles = 40, vel = 0.0, box = (10,10)) # 40 molekyler 
                                                 # med maksimal starthastighet 0
                                                 # i en lukket boks i intervallet (-10, 10)


N_tidssteg = 200000 # antall tidssteg

s.dt       = 0.001  # størrelsen på stegene

E_k = bb.np.zeros(N_tidssteg, dtype = bb.np.float_) # en array til energiene



for i in range(N_tidssteg):         # for hvert inkrement
    s.advance()           # ta et steg i tid
    E_k[i] = kinetic_energy_fast(s) # beregn kinetisk energi

# vis resultatene i en figur
bb.plt.figure(4, figsize = (8,5))
bb.plt.plot(bb.np.linspace(0,s.t, N_tidssteg), E_k)
bb.plt.ylabel("$E_K$ / enhetsløs")
bb.plt.xlabel("$tid$ / enhetsløs")
bb.plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3ce7b20895e9> in <module>
#       3                                                  # i en lukket boks i intervallet (-L, L)
#       4
# ----> 5 s = bb.box(n_bubbles = 40, vel = 0.0, box = (10,10)) # 40 molekyler
#       6                                                  # med maksimal starthastighet 0
#       7                                                  # i en lukket boks i intervallet (-10, 10)
#
# NameError: name 'bb' is not defined

# %% [markdown]
# <table style="margin:0px;width:100%;height:100%;">
# <tr style="background-color:rgba(0, 0, 0, 0);width:100%">
#     <td>
# <font size="3" face="Courier New" align = "center" >
# <p>Om cellen over er kjørt korrekt skal du se en figur som viser energien som funksjon av tid. Ettersom molekylene starter ut med svært lave hastigheter, er det rimelig å forvente at de akselereres av vekselvirkningen. Den kinetiske energien er proporsjonal med kvadratet av hastigheten, så dette bør slå ut på figuren. Etter en stund forventer vi at energien fluktuerer omkring et gjennomsnitt, men at systematiske endringer over større tidsskala blir borte. Dette er en mulig indikasjon på at systemet er i likevekt.</p>
# <div class="alert alert-info" role="alert" align="left">
#         <h3>DISKUSJON</h3>
#         <p>Oppfører systemet seg som forventet? Hvordan tror du kurven for kinetisk energi over vil se ut om du lar eksperimentet pågå lengre? Foreslå en algoritme som stopper simuleringen automatisk når likevekt er oppnådd.</p>
# </div>
# </td>
# </tr>
# </table>

# %% [markdown]
# ---

# %% [markdown]
# # Lesestoff
#
# <div class="alert alert-warning" role="alert">
# Braun, E., Gilmer, J., Mayes, H. B., Mobley, D. L., Monroe, J. I., Prasad, S., & Zuckerman, D. M. (2019). <a href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6884151/">Best practices for foundations in molecular simulations [Article v1. 0].</a> Living journal of computational molecular science, 1(1).
# </div>

# %% [markdown]
# ---

# %% [markdown]
# # Innleveringsoppgaver
# <table style="margin:0px;width:100%;height:100%;">
# <tr style="background-color:rgba(0, 0, 0, 0);width:100%">
#     <td>
# <font size="3" face="Courier New" align = "center" >
# <p>Følgende oppgaver skal leveres inn. Du fører inn svarene i et eget dokument (Word, Latex eller lignende), og leverer som en pdf-fil på Canvas. Vi oppfordrer til å samarbeide og diskutere med andre, men merk deg at figurene og resultatene som leveres inn skal være dine egne.
#     </p>
#     <p>Hensikten med disse oppgaven er å lære deg hvordan du setter opp ulike systemer, og hvordan du samler inn, fortolker og presenterer data fra beregningene dine. Du må besvare alle oppgavene som best du kan for å få innleveringen godkjent.</p>
#     <p></p>
# </td>
# </tr>
# </table>

# %% [markdown]
# <div class="alert alert-info" role="alert" align="left">
#     <font size="3" face="Courier New" align = "center" >
#         <h3>OPPGAVE 1 - Randbetingelser</h3>
#         <p>I kodecellen under har vi klargjort et system som etterligner et todimensjonalt rør hvor et heterogent molekylsystem beveger seg oppover. Når de forlater den øvre randen benytter vi såkalte <i>periodiske randbetingelser</i> for å transportere dem tilbake inn i røret i den andre enden. Slike betingelser er en god tilnærming på et uendelig langt rør langs y-aksen. Legg merke til minustegnet i "box"-parameteren.</p>
#         <p>(a) Kjør kodecellen og observer hva som skjer over en tidsperiode på ca. 1 minutt. Beskriv molekylene oppførsel, enkeltvis og systemet på helhet. Er systemet i likevekt ved tiden 0? Besvarelsen skal inneholde et stillbilde av systemet med forklarende tekst.</p>
#         <p>(b) Rediger kodecellen slik at partiklene transporteres gjennom et horisontalt rør, fra venstre til høyre. Besvarelsen behøver kun å inneholde et stillbilde - ikke kode.</p>
# </div>

# %%
# %matplotlib notebook  
import hylleraas.bubblebox as bb
import matplotlib.pyplot as plt
import numpy as np
  

s = bb.box(masses = np.random.randint(1,5,400), box = (30,-30))
s.dt = 0.01 


s.vel_[1,:] = -1


s.run()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %% [markdown]
# <div class="alert alert-info" role="alert" align="left">
#     <font size="3" face="Courier New" align = "center" >
#         <h3>OPPGAVE 2 - Initialbetingelser</h3>
#         <p>Vi skal se på et system hvor molekylene kondenserer til en gitterstruktur. I kodecellen under har vi satt opp et system med periodiske randbetingelser langs alle vegger. Initialbetingelsene er her gitt ved de hastighetene og posisjonene vi gir molekylene ved tiden 0, og slik kodecellen er satt opp nå står de <i>helt</i> stille i et kvadratisk gitter med <i>eksakt lik</i> avstand til alle naboer når vi starter simuleringen.
#         </p>
#         <p>(a) Basert på hva du vet om dette systemet så langt, skriv noen setninger om hvordan du forventer at systemet utvikler seg når tiden startes. Kjør deretter kodecellen og kommenter hvorvidt forventningene dine stemmer.</p>
#         <p>(b) Linjen "s.vel[0,0] = 0.01" er kommentert ut. Denne linjen vil gi molekyl $0$ farten $0.1$ i x-retning. Hva forventer du vil skje om du aktiverer linjen og kjører koden på nytt? Igjen, skriv noen setninger før du prøver det ut, og kommenter og forklar hva som skjer. Vis et bilde av simuleringen din i oppgavebesvarelsen.</p>
#         <p>(c) Beskriv systemets likevektstilstand med noen få setninger.</p>
# </div>

# %%
# %matplotlib notebook  
import bubblebox as bb
import matplotlib.pyplot as plt
import numpy as np

sqrt_N_molecules = 20 # kvadratroten av antall molecules (vær forsiktig, du får 20**2 antall molekyler)

s = bb.box(n_bubbles = sqrt_N_molecules**2, box = (-11,-11), vel = 0.0)

s.vel[0,0] = 0.01  # Aktiver denne linjen i oppgave (b)


# Tidssteg
s.dt = 0.005


# Initialbetingelser
count = 0
dn = np.linspace(0, 2*s.Lx, sqrt_N_molecules+1)[1]*.5
for i in np.linspace(-s.Lx, s.Lx, sqrt_N_molecules+1)[:-1]:
    for j in np.linspace(-s.Ly, s.Ly, sqrt_N_molecules+1)[:-1]:
        s.pos[:, count] = [i+dn,j+dn]
        count += 1

# Kjør simuleringen 
s.run(8,1)

# %% [markdown]
# <div class="alert alert-info" role="alert" align="left">
#     <font size="3" face="Courier New" align = "center" >
#         <h3>OPPGAVE 3 - Temperatur</h3>
#         <p>På laboratoriet måler vi temperatur med et termometer. I modellen vår må vi finne et egnet uttrykk for temperatur basert på de størrelsene vi har tilgang på. En mulighet er å ta utgangspunkt i den kinetiske energien, hvilket gir oss den såkalte kinetiske temperaturen:</p>
#         \begin{equation}
#         T = \frac{1}{N} \sum_i E_{K,i}, \quad \quad (5)
#         \end{equation}
#         <p>hvor $E_{K,i}$ er definert ved ligning (3) og $N$ er antall molekyler. Med andre ord er dette en gjennomsnittlig kinetisk energi.</p>
#         <p> I kodecellen under har vi satt opp et system hvor molekylene i boksens venstre side står stille, mens molekylene i boksens høyre side starter ut med en hastighet. Alle partiklene starter ut med lik avstand til naboene slik som i oppgave 2. Vi skal undersøke hvordan temperaturen endrer seg over tid i venstre- og høyre halvside av boksen, og har derfor skrevet en funksjon som beregner temperaturen i hver halvside på et gitt tidspunkt.<p>
#         <p> (a) Er temperaturen $T$ i likning (5) ekstensiv eller intensiv? Begrunn svaret.</p>
#         <p> (b) Kjør kodecellen og observer endringene. Lagre to bilder av figuren, ett tidlig og et annet sent i kjøringen, og skriv en kort forklaring til hva som skjer.</p>
#         <p> (c) Deaktiver den interaktive kjøringa, og aktiver de utkommenterte linjene på slutten av kodecellen. Når du så kjører cellen på nytt vil du samle inn data til å produsere en figur som viser temperatur i venstre og høyre side av boksen som funksjon av tid. Figuren kan lages ved å kjøre påfølgende kodecelle. Gi aksene titler og skriv en forklaring til figuren.</p>
# </div>

# %%
# %matplotlib notebook  
import hylleraas.bubblebox as bb
import matplotlib.pyplot as plt
import numpy as np

sqrt_N_molecules = 20 # kvadratroten av antall molecules (vær forsiktig, du får 20**2 antall molekyler)

s = bb.box(n_bubbles = sqrt_N_molecules**2, box = (41,41), vel = 0.0)


# Tidssteg
s.dt = 0.002

# Initialbetingelser - posisjon
count = 0
dn = np.linspace(0, 2*s.Lx, sqrt_N_molecules+1)[1]*.5
for i in np.linspace(-s.Lx, s.Lx, sqrt_N_molecules+1)[:-1]:
    for j in np.linspace(-s.Ly, s.Ly, sqrt_N_molecules+1)[:-1]:
        s.pos[:, count] = [i+dn,j+dn]
        count += 1
                
# Initialbetingelser - hastighet ulik null for alle molekyler til høyre
s.vel[:, s.pos[0]>0] = np.random.uniform(-5,5,(2,np.sum(s.pos[0]>0)) ) 


# Funksjon for å måle temperatur i hvert halvkammer
def temperature_split(system):
    particle_indices = np.arange(s.N_bubbles, dtype = np.int_)
    pi_left  = particle_indices[system.pos[0,:]< 0]
    N_left   = len(pi_left)
    
    pi_right = particle_indices[system.pos[0,:]>=0]
    N_right   = len(pi_right)
    
    E_K_left = .5*bb.np.sum(system.masses[pi_left]*bb.np.sum(system.vel_[:,pi_left]**2, axis = 0))
    
    E_K_right = .5*bb.np.sum(system.masses[pi_right]*bb.np.sum(system.vel_[:,pi_right]**2, axis = 0))
    
    T_left  = E_K_left/N_left
    T_right = E_K_right/N_right
    
    return T_left, T_right
    
# Kjør simuleringen 
s.run(10,5)



# Samle inn data
#T_l = []
#T_r = []

#Nt = 30000
#for i in range(Nt):
#    s.advance(dt = 0.005)
#    T_left, T_right = temperature_split(s)
#    T_l.append(T_left)
#    T_r.append(T_right)
# Out:
# Traceback (most recent call last):
#   File "C:\Users\rcort\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 216, in process
#     func(*args, **kwargs)
#   File "C:\Users\rcort\anaconda3\lib\site-packages\matplotlib\animation.py", line 1465, in _stop
#     self.event_source.remove_callback(self._loop_delay)
# AttributeError: 'NoneType' object has no attribute 'remove_callback'
# <img src="data:image/png;base64,..." width="400">

# %%
plt.figure(200, figsize = (8,6))
plt.plot(np.linspace(0,s.t, Nt), T_l, label = "Venstre side")
plt.plot(np.linspace(0,s.t, Nt), T_r, label = "Høyre side")
plt.legend()
plt.show()

# %% [markdown]
# <nav aria-label="Page navigation example, You can use for series of notebooks">
#   <ul class="pagination">
#     <li class="page-item"><a class="page-link" href="#menu">Previous</a></li>
#     <li class="page-item"><a class="page-link" href="https://www.kaggle.com/marcovasquez/machine-learning-for-beginners">1</a></li>
#     <li class="page-item"><a class="page-link" href="https://www.kaggle.com/marcovasquez/basic-eda-categoricals-values">2</a></li>
#     <li class="page-item"><a class="page-link" href="https://www.kaggle.com/marcovasquez/basic-eda-data-visualization-plots">3</a></li>
#     <li class="page-item"><a class="page-link" href="#menu">Next</a></li>
#   </ul>
# </nav>

# %% [markdown]
# <div class="alert alert-info" role="alert">

# %%
pwd
